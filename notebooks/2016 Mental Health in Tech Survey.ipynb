# %%
import pandas as pd
pd.set_option('display.max_columns', None)
# %matplotlib inline
df = pd.read_csv('mental-heath-in-tech-2016_20161114.csv')
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                  6-25
# 2                                                  6-25
# 3                                                   NaN
# 4                                                  6-25
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...

# %%
df.describe(include=['O'])
# Out:
#        How many employees does your company or organization have?  \
# count                                                1146
# unique                                                  6
# top                                                26-100
# freq                                                  292
#
#        Does your employer provide mental health benefits as part of healthcare coverage?  \
# count                                                1146
# unique                                                  4
# top                                                   Yes
# freq                                                  531
#
#        Do you know the options for mental health care available under your employer-provided coverage?  \
# count                                                1013
# unique                                                  3
# top                                                    No
# freq                                                  354
#
# ...

# %%
df.describe(include=['O']).isnull().sum()
# Out:
# How many employees does your company or organization have?                                                                                                                          0
# Does your employer provide mental health benefits as part of healthcare coverage?                                                                                                   0
# Do you know the options for mental health care available under your employer-provided coverage?                                                                                     0
# Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?                                              0
# Does your employer offer resources to learn more about mental health concerns and options for seeking help?                                                                         0
# ...

# %%
df.isnull().sum()
# Out:
# Are you self-employed?                                                                  0
# How many employees does your company or organization have?                            287
# Is your employer primarily a tech company/organization?                               287
# Is your primary role within your company related to tech/IT?                         1170
# Does your employer provide mental health benefits as part of healthcare coverage?     287
#                                                                                      ...
# What US state or territory do you live in?                                            593
# What country do you work in?                                                            0
# What US state or territory do you work in?                                            582
# Which of the following best describes your work position?                               0
# ...

# %%
df.shape
# Out:
# (1433, 63)

# %%
df.dtypes
# Out:
# Are you self-employed?                                                                 int64
# How many employees does your company or organization have?                            object
# Is your employer primarily a tech company/organization?                              float64
# Is your primary role within your company related to tech/IT?                         float64
# Does your employer provide mental health benefits as part of healthcare coverage?     object
#                                                                                       ...
# What US state or territory do you live in?                                            object
# What country do you work in?                                                          object
# What US state or territory do you work in?                                            object
# Which of the following best describes your work position?                             object
# ...

# %%
df.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#   How many employees does your company or organization have?  \
# 0                                             26-100
# 1                                               6-25
# 2                                               6-25
# 3                                                NaN
# 4                                               6-25
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                NaN
# 4                                                0.0
#
#    Is your primary role within your company related to tech/IT?  \
# 0                                                NaN
# ...

# %%
pd.set_option(
    'display.max_colwidth', 100
)

# %%
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                        26-100
# 1                                                          6-25
# 2                                                          6-25
# 3                                                           NaN
# 4                                                          6-25
# ...                                                         ...
# 1428                                                        NaN
# 1429                                                        NaN
# ...

# %%
df['Are you self-employed?'].value_counts()
# Out:
# 0    1146
# 1     287
# Name: Are you self-employed?, dtype: int64

# %%
df['Is your employer primarily a tech company/organization?'].value_counts()
# Out:
# 1.0    883
# 0.0    263
# Name: Is your employer primarily a tech company/organization?, dtype: int64

# %%
df['Is your primary role within your company related to tech/IT?'].value_counts()
# Out:
# 1.0    248
# 0.0     15
# Name: Is your primary role within your company related to tech/IT?, dtype: int64

# %%
# age distribution for 2016
df['What is your age?'].describe()
# Out:
# count    1433.000000
# mean       34.286113
# std        11.290931
# min         3.000000
# 25%        28.000000
# 50%        33.000000
# 75%        39.000000
# max       323.000000
# Name: What is your age?, dtype: float64

# %%
df['What is your age?'].dtypes
# Out:
# dtype('int64')

# %%
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sns
#df['What is your age?'].isna().sum()

# %%
# max is 323 which cant be the case. I'll consider first valid age 
df_age = df[(df['What is your age?'] < 100) & (df['What is your age?'] > 0)]
df_age['What is your age?'].hist();

# %%
plt.figure(figsize= (10,10))
sns.countplot(y = df['What is your age?']);

# %%
#df['What is your age?'] = [i.replace(i, '33') if i in to_replace else i for i in df['What is your age?']]

# %%
# Create a threshold for percent below to become "other"
#threshold = .027
#target_col = df['What is your age?']
# Create a list of each string that occurs below that threshold
#to_replace = target_col.value_counts()[target_col.value_counts(normalize=True) < threshold].keys()
# Replace instances of target vals
#target_col = [i.replace(i, 'other') if i in to_replace else i for i in target_col]

# %%
#company_size = df[df['How many employees does your company or organization have?']]
#company_size['How many employees does your company or organization have?'].hist();

# %%
pd.set_option('display.max_columns', None)
df['Which of the following best describes your work position?'].value_counts()
# Out:
# Back-end Developer                                                                                     263
# Front-end Developer                                                                                    125
# Other                                                                                                  112
# Supervisor/Team Lead                                                                                    68
# Back-end Developer|Front-end Developer                                                                  61
#                                                                                                       ...
# Back-end Developer|Support|Supervisor/Team Lead                                                          1
# Front-end Developer|Designer|One-person shop                                                             1
# Supervisor/Team Lead|Front-end Developer|Back-end Developer|DevOps/SysAdmin|Dev Evangelist/Advocate      1
# ...

# %%
df['Which of the following best describes your work position?'].dtype
# Out:
# dtype('O')

# %%
df['Which of the following best describes your work position?'] = df['Which of the following best describes your work position?'].astype(object)

# %%
df['Which of the following best describes your work position?'].dtype
# Out:
# dtype('O')

# %%
df['Which of the following best describes your work position?'].unique()
# Out:
# array(['Back-end Developer', 'Back-end Developer|Front-end Developer',
#        'Supervisor/Team Lead',
#        'Executive Leadership|Supervisor/Team Lead|Dev Evangelist/Advocate|DevOps/SysAdmin|Support|Back-end Developer|Front-end Developer',
#        'DevOps/SysAdmin|Support|Back-end Developer|Front-end Developer|Designer',
#        'Dev Evangelist/Advocate|Back-end Developer',
#        'Support|Back-end Developer|One-person shop',
#        'One-person shop|Front-end Developer|Back-end Developer',
#        'Front-end Developer', 'Executive Leadership',
#        'Supervisor/Team Lead|Dev Evangelist/Advocate|Back-end Developer|Front-end Developer',
#        'DevOps/SysAdmin|Back-end Developer|Front-end Developer',
#        'Designer', 'Other|Executive Leadership', 'One-person shop',
#        'Other', 'Supervisor/Team Lead|Support|Back-end Developer',
#        'Supervisor/Team Lead|DevOps/SysAdmin|Back-end Developer',
# ...

# %%
df['Which of the following best describes your work position?'].nunique()
# Out:
# 264

# %%
# Simplify to ~10 primary types of work positions
Supervisor = df['Which of the following best describes your work position?'].str.contains('Supervisor')
Executive = df['Which of the following best describes your work position?'].str.contains('Executive')
HR = df['Which of the following best describes your work position?'].str.contains('HR')
df['Which of the following best describes your work position?'].nunique()
# Out:
# 264

# %%
#df[df['Which of the following best describes your work position?'].str.contains('Supervisor')] = 'Supervisor'
#df[df['Which of the following best describes your work position?'].str.contains('Executive')] = 'Executive'
#df[df['Which of the following best describes your work position?'].str.contains('HR')] = 'HR'

# %%
df['Which of the following best describes your work position?']
# Out:
# 0                                                                                        Back-end Developer
# 1                                                                    Back-end Developer|Front-end Developer
# 2                                                                                        Back-end Developer
# 3                                                                                      Supervisor/Team Lead
# 4       Executive Leadership|Supervisor/Team Lead|Dev Evangelist/Advocate|DevOps/SysAdmin|Support|Back-e...
#                                                        ...
# 1428                                                                                                  Other
# 1429                                                                                                Support
# 1430                                                                                     Back-end Developer
# ...

# %%
df.loc[Supervisor, 'Which of the following best describes your work position?'] = 'Supervisor'
df.loc[Executive, 'Which of the following best describes your work position?'] = 'Executive'
df.loc[HR, 'Which of the following best describes your work position?'] = 'HR'

df['Which of the following best describes your work position?'].value_counts()
# Out:
# Back-end Developer                                                                      263
# Supervisor                                                                              238
# Front-end Developer                                                                     125
# Other                                                                                   112
# Executive                                                                                97
#                                                                                        ...
# One-person shop|Front-end Developer|Back-end Developer|Sales|Support|DevOps/SysAdmin      1
# DevOps/SysAdmin|Designer|Front-end Developer|Back-end Developer                           1
# Support|Back-end Developer|Front-end Developer|Designer                                   1
# Designer|One-person shop                                                                  1
# ...

# %%
df['Which of the following best describes your work position?'].nunique()
# Out:
# 134

# %%
#for (x) in df['Which of the following best describes your work position?']:
   #x = x.split('/', 1)[0];

# %%
df['Which of the following best describes your work position?']
# Out:
# 0                           Back-end Developer
# 1       Back-end Developer|Front-end Developer
# 2                           Back-end Developer
# 3                                   Supervisor
# 4                                    Executive
#                          ...
# 1428                                     Other
# 1429                                   Support
# 1430                        Back-end Developer
# 1431                           DevOps/SysAdmin
# 1432                                     Other
# Name: Which of the following best describes your work position?, Length: 1433, dtype: object

# %%
df['Which of the following best describes your work position?'].nunique()
# Out:
# 134

# %%
df['Which of the following best describes your work position?'] = df['Which of the following best describes your work position?'].replace('Back-end Developer|Front-end Developer', 'Full-stack Developer')
df['Which of the following best describes your work position?'] = df['Which of the following best describes your work position?'].replace('Front-end Developer|Back-end Developer', 'Full-stack Developer')
df['Which of the following best describes your work position?']
# Out:
# 0         Back-end Developer
# 1       Full-stack Developer
# 2         Back-end Developer
# 3                 Supervisor
# 4                  Executive
#                 ...
# 1428                   Other
# 1429                 Support
# 1430      Back-end Developer
# 1431         DevOps/SysAdmin
# 1432                   Other
# Name: Which of the following best describes your work position?, Length: 1433, dtype: object

# %%
# Simplify to ~10 primary types of work positions
#Supervisor = df['Which of the following best describes your work position?'].str.contains('Supervisor')
#Executive = df['Which of the following best describes your work position?'].str.contains('Executive')
#HR = df['Which of the following best describes your work position?'].str.contains('HR')
df['Which of the following best describes your work position?'].nunique()
# Out:
# 133

# %%
df['Which of the following best describes your work position?'] = df['Which of the following best describes your work position?'].apply(lambda x: x.split('|')[0])
df['Which of the following best describes your work position?']
# Out:
# 0         Back-end Developer
# 1       Full-stack Developer
# 2         Back-end Developer
# 3                 Supervisor
# 4                  Executive
#                 ...
# 1428                   Other
# 1429                 Support
# 1430      Back-end Developer
# 1431         DevOps/SysAdmin
# 1432                   Other
# Name: Which of the following best describes your work position?, Length: 1433, dtype: object

# %%
#df.loc[Supervisor, 'Which of the following best describes your work position?'] = 'Supervisor'
#df.loc[Executive, 'Which of the following best describes your work position?'] = 'Executive'
#df.loc[HR, 'Which of the following best describes your work position?'] = 'HR'

df['Which of the following best describes your work position?'].value_counts()
# Out:
# Back-end Developer         296
# Supervisor                 238
# Front-end Developer        171
# Other                      144
# DevOps/SysAdmin            130
# Full-stack Developer       101
# Executive                   97
# One-person shop             91
# Support                     62
# Dev Evangelist/Advocate     50
# Designer                    37
# HR                          12
# Sales                        4
# Name: Which of the following best describes your work position?, dtype: int64

# %%
#target = 'If yes, what condition(s) have you been diagnosed with?'

# %%
df['If yes, what condition(s) have you been diagnosed with?'].value_counts()
# Out:
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                   117
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                                                                       102
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                                                                                                      47
# ...

# %%
df['If yes, what condition(s) have you been diagnosed with?'].nunique()
# Out:
# 128

# %%
#df2 = df[df['If yes, what condition(s) have you been diagnosed with?'].value_counts(normalize=True) > 4]
#df2 = df[df['If yes, what condition(s) have you been diagnosed with?'].value_counts() < 5 ].index
#df2

# %%
df['If yes, what condition(s) have you been diagnosed with?']
# Out:
# 0                                                                                                       NaN
# 1       Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder,...
# 2                                                                                                       NaN
# 3       Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder,...
# 4                             Anxiety Disorder (Generalized, Social, Phobia, etc)|Stress Response Syndromes
#                                                        ...
# 1428                                                                                                    NaN
# 1429                                                                                                    NaN
# 1430                                                                                                    NaN
# ...

# %%
df['If yes, what condition(s) have you been diagnosed with?'].fillna('No Response', inplace=True)
df['If yes, what condition(s) have you been diagnosed with?']
# Out:
# 0                                                                                               No Response
# 1       Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder,...
# 2                                                                                               No Response
# 3       Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder,...
# 4                             Anxiety Disorder (Generalized, Social, Phobia, etc)|Stress Response Syndromes
#                                                        ...
# 1428                                                                                            No Response
# 1429                                                                                            No Response
# 1430                                                                                            No Response
# ...

# %%
df['If yes, what condition(s) have you been diagnosed with?'].value_counts()
# Out:
# No Response                                                                                                                                                                                                                                                                             865
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                   117
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                                                                       102
# ...

# %%
sample = df['If yes, what condition(s) have you been diagnosed with?'].value_counts()
df['If yes, what condition(s) have you been diagnosed with?'] = np.where(df['If yes, what condition(s) have you been diagnosed with?'].isin(sample.index[sample >= 5]), df['If yes, what condition(s) have you been diagnosed with?'], 'Other')

# %%
df['If yes, what condition(s) have you been diagnosed with?'].value_counts()
# Out:
# No Response                                                                                                                                        865
# Other                                                                                                                                              154
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                              117
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                  102
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                 47
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder      26
# ...

# %%
df['If yes, what condition(s) have you been diagnosed with?'].nunique()
# Out:
# 19

# %%
# Sex column needs to be recoded (number of unique values = 70)
df['What is your gender?'].replace(to_replace = ['Male', 'male', 'Male ', 'M', 'm',
       'man', 'Cis male', 'Male.', 'male 9:1 female, roughly', 'Male (cis)', 'Man', 'Sex is male',
       'cis male', 'Malr', 'Dude', "I'm a man why didn't you make this a drop down question. You should of asked sex? And I would of answered yes please. Seriously how much text can this take? ",
       'mail', 'M|', 'Male/genderqueer', 'male ',
       'Cis Male', 'Male (trans, FtM)',
       'cisdude', 'cis man', 'MALE'], value = 1, inplace = True)

df['What is your gender?'].replace(to_replace = ['Female', 'female', 'I identify as female.', 'female ',
       'Female assigned at birth ', 'F', 'Woman', 'fm', 'f', 'Cis female ', 'Transitioned, M2F',
       'Genderfluid (born female)', 'Female or Multi-Gender Femme', 'Female ', 'woman', 'female/woman',
       'Cisgender Female', 'fem', 'Female (props for making this a freeform field, though)',
       ' Female', 'Cis-woman', 'female-bodied; no feelings about gender',
       'AFAB'], value = 2, inplace = True)

df['What is your gender?'].replace(to_replace = ['Bigender', 'non-binary', 'Other/Transfeminine',
       'Androgynous', 'Other', 'nb masculine',
       'none of your business', 'genderqueer', 'Human', 'Genderfluid',
       'Enby', 'genderqueer woman', 'mtf', 'Queer', 'Agender', 'Fluid',
       'Nonbinary', 'human', 'Unicorn', 'Genderqueer',
       'Genderflux demi-girl', 'Transgender woman'], value = 3, inplace = True)

df['What is your gender?'].nunique()
# Out:
# 3

# %%
#rep_col = 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'
#di = {'No': 0, 'Yes': 1, 'Maybe': , 'Sometimes': }
#rep_col2 = 'Do you believe your productivity is ever affected by a mental health issue?'

#df[rep_col2] =
#df[rep_col].replace(di, inplace=True)

# %%
rep_col = 'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'
di = {'No': 0, 'Yes': 1}

df[rep_col].replace(di, inplace=True)

# %%
df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?']
# Out:
# 0         0
# 1         1
# 2         0
# 3       NaN
# 4         0
#        ...
# 1428    NaN
# 1429    NaN
# 1430      1
# 1431      0
# 1432      0
# Name: Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?, Length: 1433, dtype: object

# %%
df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'].nunique()
# Out:
# 3

# %%
#converting cat features with 2 unique variables into numerical scales

'Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?'
'Have you been diagnosed with a mental health condition by a medical professional?'
di = {'No': 0, 'Yes': 1}

#df[rep_col].replace(di2, inplace=True)
df['Have you heard of or observed negative consequences for co-workers who have been open about mental health issues in your workplace?'].replace(di, inplace=True)
df['Have you been diagnosed with a mental health condition by a medical professional?'].replace(di, inplace=True)

# %%
#converting cat features with 3 unique variables into numerical scales
'Do you know the options for mental health care available under your employer-provided coverage?'
'Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'
'Does your employer offer resources to learn more about mental health concerns and options for seeking help?'
'Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?'
'Do you think that discussing a mental health disorder with your employer would have negative consequences?' 
'Do you think that discussing a physical health issue with your employer would have negative consequences?' 
'Would you feel comfortable discussing a mental health disorder with your coworkers?'
'Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?'
'Do you feel that your employer takes mental health as seriously as physical health?' 
'Do you know local or online resources to seek help for a mental health disorder?' 
'If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?' 
'Did your previous employers provide resources to learn more about mental health issues and how to seek help?' 
'Do you think that discussing a physical health issue with previous employers would have negative consequences?'
'Would you have been willing to discuss a mental health issue with your previous co-workers?'
'Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?'
'Would you be willing to bring up a physical health issue with a potential employer in an interview?'
'Would you bring up a mental health issue with a potential employer in an interview?'
'Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?'
'Do you have a family history of mental illness?' 
'Have you had a mental health disorder in the past?'
'Do you currently have a mental health disorder?'
'Do you work remotely?'
di2 = {'No, at none of my previous employers': 0, 'No': 0, 'None did': 0, 'None of them': 0, "No, I don't know any": 0, 'Never': 0, "I don't know": 1, 'Maybe': 1, 'Sometimes': 1, "I am not sure": 1, "I'm not sure": 1, 'Some of them': 1, 'I know some': 1, 'Some did': 1, 'Some of my previous employers': 1, 'Yes': 2, 'Yes, I know several': 2, 'Yes, all of them': 2, 'Yes, at all of my previous employers': 2, 'Always': 2}

df['Do you know the options for mental health care available under your employer-provided coverage?'].replace(di2, inplace=True)
df['Has your employer ever formally discussed mental health (for example, as part of a wellness campaign or other official communication)?'].replace(di2, inplace=True)
df['Does your employer offer resources to learn more about mental health concerns and options for seeking help?'].replace(di2, inplace=True)
df['Is your anonymity protected if you choose to take advantage of mental health or substance abuse treatment resources provided by your employer?'].replace(di2, inplace=True)
df['Do you think that discussing a mental health disorder with your employer would have negative consequences?'].replace(di2, inplace=True)
df['Do you think that discussing a physical health issue with your employer would have negative consequences?'].replace(di2, inplace=True) 
df['Would you feel comfortable discussing a mental health disorder with your coworkers?'].replace(di2, inplace=True)
df['Would you feel comfortable discussing a mental health disorder with your direct supervisor(s)?'].replace(di2, inplace=True)
df['Do you feel that your employer takes mental health as seriously as physical health?'].replace(di2, inplace=True) 
df['Do you know local or online resources to seek help for a mental health disorder?'].replace(di2, inplace=True) 
df['If you have revealed a mental health issue to a client or business contact, do you believe this has impacted you negatively?'].replace(di2, inplace=True) 
df['Did your previous employers provide resources to learn more about mental health issues and how to seek help?'].replace(di2, inplace=True) 
df['Do you think that discussing a physical health issue with previous employers would have negative consequences?'].replace(di2, inplace=True)
df['Would you have been willing to discuss a mental health issue with your previous co-workers?'].replace(di2, inplace=True)
df['Did you hear of or observe negative consequences for co-workers with mental health issues in your previous workplaces?'].replace(di2, inplace=True)
df['Would you be willing to bring up a physical health issue with a potential employer in an interview?'].replace(di2, inplace=True)
df['Would you bring up a mental health issue with a potential employer in an interview?'].replace(di2, inplace=True)
df['Have your observations of how another individual who discussed a mental health disorder made you less likely to reveal a mental health issue yourself in your current workplace?'].replace(di2, inplace=True)
df['Do you have a family history of mental illness?'].replace(di2, inplace=True) 
df['Have you had a mental health disorder in the past?'].replace(di2, inplace=True)
df['Do you currently have a mental health disorder?'].replace(di2, inplace=True)
df['Do you work remotely?'].replace(di2, inplace=True)

# %%
# converting NA values of 4 unique cat variable columns into NaNs
df['Does your employer provide mental health benefits as part of healthcare coverage?'] = df['Does your employer provide mental health benefits as part of healthcare coverage?'].replace('Not eligible for coverage / N/A', np.nan)
print(df['Does your employer provide mental health benefits as part of healthcare coverage?'].isnull().sum())
df['If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?'] = df['If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?'].replace('Not applicable to me', np.nan)
print(df['If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?'].isnull().sum())
df['Do you believe your productivity is ever affected by a mental health issue?'] = df['Do you believe your productivity is ever affected by a mental health issue?'].replace('Not applicable to me', np.nan)
print(df['Do you believe your productivity is ever affected by a mental health issue?'].isnull().sum())
df['Were you aware of the options for mental health care provided by your previous employers?'] = df['Were you aware of the options for mental health care provided by your previous employers?'].replace('N/A (not currently aware)', np.nan)
print(df['Were you aware of the options for mental health care provided by your previous employers?'].isnull().sum())

'Does your employer provide mental health benefits as part of healthcare coverage?'
'If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?'
'Do you believe your productivity is ever affected by a mental health issue?'
'Were you aware of the options for mental health care provided by your previous employers?'
di3_NAs = {'No': 0, 'No, I only became aware later': 0, "I don't know": 1, "I'm not sure": 1, 'Unsure': 1, 'I was aware of some': 1, 'Yes': 2, 'Yes, I was aware of all of them': 2}

df['Does your employer provide mental health benefits as part of healthcare coverage?'].replace(di3_NAs, inplace=True)
df['If you have revealed a mental health issue to a coworker or employee, do you believe this has impacted you negatively?'].replace(di3_NAs, inplace=True)
df['Do you believe your productivity is ever affected by a mental health issue?'].replace(di3_NAs, inplace=True)
df['Were you aware of the options for mental health care provided by your previous employers?'].replace(di3_NAs, inplace=True)
# Out:
# 370
# 1279
# 1177
# 751

# %%
df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'].value_counts()
# Out:
# 1-25%      92
# 26-50%     72
# 51-75%     26
# 76-100%    14
# Name: If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?, dtype: int64

# %%
#converting cat features with 4 unique variables into numerical scales
#*'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'
'Have your previous employers provided mental health benefits?'
'Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?'
'Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?'
'Do you think that discussing a mental health disorder with previous employers would have negative consequences?'
'Would you have been willing to discuss a mental health issue with your direct supervisor(s)?'
'Did you feel that your previous employers took mental health as seriously as physical health?'
'Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?'
di3 = {'No, at none of my previous employers': 0, 'No': 0, 'No, none did': 0, 'None did': 0, 'None of them': 0, 'No, at none of my previous employers': 0, 'Maybe/Not sure': 1, "I don't know": 1, "Some did": 2, 'Sometimes': 2, 'Some of them': 2, 'Some of my previous employers': 2, 'Yes, I observed': 2, 'Yes, they all did': 3, 'Yes, at all of my previous employers': 3, 'Yes, always': 3, 'Yes, all of them': 3, 'Yes, I experienced': 3}

df['Have your previous employers provided mental health benefits?'].replace(di3, inplace=True)
df['Did your previous employers ever formally discuss mental health (as part of a wellness campaign or other official communication)?'].replace(di3, inplace=True)
df['Was your anonymity protected if you chose to take advantage of mental health or substance abuse treatment resources with previous employers?'].replace(di3, inplace=True)
df['Do you think that discussing a mental health disorder with previous employers would have negative consequences?'].replace(di3, inplace=True)
df['Would you have been willing to discuss a mental health issue with your direct supervisor(s)?'].replace(di3, inplace=True)
df['Did you feel that your previous employers took mental health as seriously as physical health?'].replace(di3, inplace=True)
df['Have you observed or experienced an unsupportive or badly handled response to a mental health issue in your current or previous workplace?'].replace(di3, inplace=True)

# %%
# converting NA values of 5 unique cat variable columns into NaNs
df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?'] = df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?'].replace('Not applicable to me', np.nan)
print(df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?'].isnull().sum())
df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?'] = df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?'].replace('Not applicable to me', np.nan)
print(df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?'].isnull().sum())
df['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'] = df['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].replace('Not applicable to me', np.nan)
print(df['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].isnull().sum())
df['If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?'] = df['If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?'].replace('Not applicable to me', np.nan)
print(df['If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?'].isnull().sum())

'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?'
'If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?'
'If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'
'If you have a mental health issue, do you feel that it interferes with your work when being NOT treated effectively?'
di4_NAs = {'No, because it would impact me negatively': 0, 'Never': 0, "No, because it doesn't matter": 1, 'Rarely': 1, 'Sometimes, if it comes up': 2, 'Sometimes': 2, 'Yes, always': 3, 'Often': 3}

df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to clients or business contacts?'].replace(di4_NAs, inplace=True)
df['If you have been diagnosed or treated for a mental health disorder, do you ever reveal this to coworkers or employees?'].replace(di4_NAs, inplace=True)
df['If you have a mental health issue, do you feel that it interferes with your work when being treated effectively?'].replace(di4_NAs, inplace=True)
df['If you have a mental health issue, do you feel that it interferes with your work when NOT being treated effectively?'].replace(di4_NAs, inplace=True)
# Out:
# 1247
# 1257
# 557
# 468

# %%
df['Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?'].value_counts()
# Out:
# Maybe                           591
# Yes, I think they would         403
# No, I don't think they would    348
# No, they do not                  49
# Yes, they do                     42
# Name: Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?, dtype: int64

# %%
#converting cat features with 5 unique variables into numerical scales
'Do you feel that being identified as a person with a mental health issue would hurt your career?'
'Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?'
di4 = {'No, it has not': 0, 'No, they do not': 0, "No, I don't think it would": 1, "No, I don't think they would": 1, 'Maybe': 2, 'Yes, I think it would': 3, 'Yes, I think they would': 3, 'Yes, it has': 4, 'Yes, they do': 4}

df['Do you feel that being identified as a person with a mental health issue would hurt your career?'].replace(di4, inplace=True)
df['Do you think that team members/co-workers would view you more negatively if they knew you suffered from a mental health issue?'].replace(di4, inplace=True)

# %%
df['If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:'
].value_counts()
# Out:
# Somewhat easy                 281
# Very easy                     220
# Somewhat difficult            199
# Neither easy nor difficult    178
# I don't know                  150
# Very difficult                118
# Name: If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:, dtype: int64

# %%
# converting NA values of 6 unique cat variable columns into NaNs
df['How willing would you be to share with friends and family that you have a mental illness?'] =  df['How willing would you be to share with friends and family that you have a mental illness?'].replace('Not applicable to me (I do not have a mental illness)', np.nan)
print(df['How willing would you be to share with friends and family that you have a mental illness?'].isnull().sum())

'How willing would you be to share with friends and family that you have a mental illness?'
di5_NAs = {'Not open at all': 0, 'Somewhat not open': 1, 'Neutral': 2, 'Somewhat open': 3, 'Very open': 4}
df['How willing would you be to share with friends and family that you have a mental illness?'].replace(di5_NAs, inplace=True)
# Out:
# 112

# %%
#converting cat features with 6 unique variables into numerical scales
'If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:'
#*'How many employees does your company or organization have?' (246 nans)

di5 = {'Very difficult': 0, 'Somewhat difficult': 1, "I don't know": 2, 'Neither easy nor difficult': 3, 'Somewhat easy': 4, 'Very easy': 5}
df['If a mental health issue prompted you to request a medical leave from work, asking for that leave would be:'].replace(di5, inplace=True)

# %%
#*'How many employees does your company or organization have?' (246 nans)
#*'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'

# %%
df['How many employees does your company or organization have?']
# Out:
# 0        26-100
# 1          6-25
# 2          6-25
# 3           NaN
# 4          6-25
#          ...
# 1428        NaN
# 1429        NaN
# 1430    100-500
# 1431    100-500
# 1432    100-500
# Name: How many employees does your company or organization have?, Length: 1433, dtype: object

# %%
df['How many employees does your company or organization have?'].value_counts()
# Out:
# 26-100            292
# More than 1000    256
# 100-500           248
# 6-25              210
# 500-1000           80
# 1-5                60
# Name: How many employees does your company or organization have?, dtype: int64

# %%
'How many employees does your company or organization have?'
empcount = {'1-5': 0, '6-25': 1, '26-100': 2, '100-500': 3, '500-1000': 4, 'More than 1000': 5}
df['How many employees does your company or organization have?'].replace(empcount, inplace=True)

# %%
df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?']
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3       1-25%
# 4         NaN
#         ...
# 1428      NaN
# 1429      NaN
# 1430      NaN
# 1431      NaN
# 1432      NaN
# Name: If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?, Length: 1433, dtype: object

# %%
df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'] = df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'].str.strip('%')
print (df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'])
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3       1-25
# 4        NaN
#         ...
# 1428     NaN
# 1429     NaN
# 1430     NaN
# 1431     NaN
# 1432     NaN
# Name: If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?, Length: 1433, dtype: object

# %%
df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'].value_counts()
# Out:
# 1-25      92
# 26-50     72
# 51-75     26
# 76-100    14
# Name: If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?, dtype: int64

# %%
'If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'
worktime = {'1-25': 0, '26-50': 1, '51-75': 2, '76-100': 3}
df['If yes, what percentage of your work time (time performing primary or secondary job functions) is affected by a mental health issue?'].replace(worktime, inplace=True)

# %%
df['Do you work remotely?'].value_counts()
# Out:
# 1    757
# 2    343
# 0    333
# Name: Do you work remotely?, dtype: int64

# %%
df['If maybe, what condition(s) do you believe you have?'].value_counts()
# Out:
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                               55
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                           49
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                             35
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder                                                                  10
# ...

# %%
df['If maybe, what condition(s) do you believe you have?'].fillna('Not Applicable', inplace=True)

# %%
sample2 = df['If maybe, what condition(s) do you believe you have?'].value_counts()
df['If maybe, what condition(s) do you believe you have?'] = np.where(df['If maybe, what condition(s) do you believe you have?'].isin(sample2.index[sample2 >= 4]), df['If maybe, what condition(s) do you believe you have?'], 'Other')
df['If maybe, what condition(s) do you believe you have?'].value_counts()
# Out:
# Not Applicable                                                                                                                                                        1111
# Other                                                                                                                                                                  112
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                       55
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                   49
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                     35
# ...

# %%
df['If so, what condition(s) were you diagnosed with?'].value_counts()
# Out:
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                                                                     187
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                                                 150
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                                                                                                    64
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder                                                                                         33
# ...

# %%
df['If so, what condition(s) were you diagnosed with?'].fillna('Not Applicable', inplace=True)

# %%
sample3 = df['If so, what condition(s) were you diagnosed with?'].value_counts()
df['If so, what condition(s) were you diagnosed with?'] = np.where(df['If so, what condition(s) were you diagnosed with?'].isin(sample3.index[sample3 >= 5]), df['If so, what condition(s) were you diagnosed with?'], 'Other')
df['If so, what condition(s) were you diagnosed with?'].value_counts()
# Out:
# Not Applicable                                                                                                                                    722
# Mood Disorder (Depression, Bipolar Disorder, etc)                                                                                                 187
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)                                             150
# Other                                                                                                                                             129
# Anxiety Disorder (Generalized, Social, Phobia, etc)                                                                                                64
# Anxiety Disorder (Generalized, Social, Phobia, etc)|Mood Disorder (Depression, Bipolar Disorder, etc)|Attention Deficit Hyperactivity Disorder     33
# ...

# %%
df.dtypes
# Out:
# Are you self-employed?                                                                 int64
# How many employees does your company or organization have?                           float64
# Is your employer primarily a tech company/organization?                              float64
# Is your primary role within your company related to tech/IT?                         float64
# Does your employer provide mental health benefits as part of healthcare coverage?    float64
#                                                                                       ...
# What US state or territory do you live in?                                            object
# What country do you work in?                                                          object
# What US state or territory do you work in?                                            object
# Which of the following best describes your work position?                             object
# ...

# %%
df.describe(include=['O'])
# Out:
#         Did your previous employers provide resources to learn more about mental health issues and how to seek help?  \
# count                                                                                                  1264
# unique                                                                                                    3
# top                                                                                                       0
# freq                                                                                                    842
#
#                Why or why not? Why or why not?.1  \
# count                     1095              1126
# unique                    1085              1080
# top     Fear of discrimination            Stigma
# freq                         3                14
#
#        If yes, what condition(s) have you been diagnosed with?  \
# count                                                     1433
# ...

# %%
#cols = df.columns[df.dtypes.eq('object')]
#df[cols] = df[cols].apply(pd.to_numeric, errors='coerce')
#df.dtypes

# %%
df.head()
# Out:
#    Are you self-employed?  \
# 0                       0
# 1                       0
# 2                       0
# 3                       1
# 4                       0
#
#    How many employees does your company or organization have?  \
# 0                                                         2.0
# 1                                                         1.0
# 2                                                         1.0
# 3                                                         NaN
# 4                                                         1.0
#
#    Is your employer primarily a tech company/organization?  \
# 0                                                      1.0
# 1                                                      1.0
# 2                                                      1.0
# 3                                                      NaN
# 4                                                      0.0
#
# ...

# %%
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#       How many employees does your company or organization have?  \
# 0                                                            2.0
# 1                                                            1.0
# 2                                                            1.0
# 3                                                            NaN
# 4                                                            1.0
# ...                                                          ...
# 1428                                                         NaN
# 1429                                                         NaN
# ...

# %%
df.to_csv('MHScleaned.csv', index=True)

# %%
import seaborn as sns
ax = sns.pairplot(df);

# %%
from pandas_profiling import ProfileReport
profile = ProfileReport(train, minimal=True).to_notebook_iframe()

profile

# %%
#### So, of course my df is derpf...
# Create a threshold for percent below to become "other"
threshold = .027
target_col = derpf['region']
# Create a list of each string that occurs below that threshold
to_replace = target_col.value_counts()[target_col.value_counts(normalize=True) < threshold].keys()
# Replace instances of target vals
target_col = [i.replace(i, 'other') if i in to_replace else i for i in target_col]

target_col = [i.replace(i, 'other') if i in to_replace else i for i in target_col]
